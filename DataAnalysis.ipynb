# %% [markdown]
# <a href="https://colab.research.google.com/github/toche7/StatPy/blob/main/DataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# การวิเคราะห์ข้อมูล (Data Analysis) คือกระบวนการในการตรวจสอบ ทำความสะอาด แปลงข้อมูล และสร้างแบบจำลองข้อมูลโดยมีเป้าหมายเพื่อสรุปข้อมูล ทำนาย หรือทำความเข้าใจรูปแบบและแนวโน้มในข้อมูล กระบวนการนี้มีความสำคัญในหลายสาขา เช่น ธุรกิจ วิทยาศาสตร์ เทคโนโลยี และการวิจัย เพื่อช่วยในการตัดสินใจ วางแผน และแก้ปัญหา

# %% [markdown]
# **ประเภทของการวิเคราะห์ข้อมูล**
# - การวิเคราะห์เชิงพรรณนา (Descriptive Analysis): มุ่งเน้นการสรุปและอธิบายข้อมูล เช่น การหาค่าเฉลี่ย ค่ามัธยฐาน การกระจายข้อมูล เพื่อให้เข้าใจภาพรวมของข้อมูลเบื้องต้น
# - การวิเคราะห์เชิงสาเหตุ (Diagnostic Analysis): มุ่งเน้นการค้นหาสาเหตุของเหตุการณ์หรือผลลัพธ์บางอย่าง เช่น การวิเคราะห์ปัจจัยที่ส่งผลต่อการลดลงของยอดขาย
# - การวิเคราะห์เชิงพยากรณ์ (Predictive Analysis): ใช้ข้อมูลในอดีตในการทำนายแนวโน้มและเหตุการณ์ในอนาคต โดยใช้เทคนิคการสร้างแบบจำลองทางสถิติและการเรียนรู้ของเครื่อง (Machine Learning)
# - การวิเคราะห์เชิงสั่งการ (Prescriptive Analysis): เป็นการให้คำแนะนำหรือการตัดสินใจเชิงปฏิบัติจากข้อมูล เช่น การแนะนำกลยุทธ์ที่ดีที่สุดในการเพิ่มกำไรหรือการแก้ปัญหาที่เกิดขึ้น
# เครื่องมือที่ใช้ในกระบวนการวิเคราะห์ข้อมูล
#
# เครื่องมือที่นิยมใช้สำหรับการวิเคราะห์ข้อมูล ได้แก่:
#
# - ซอฟต์แวร์สถิติ เช่น SPSS, SAS
# - ซอฟต์แวร์การเขียนโปรแกรม เช่น Python, R
# - เครื่องมือแสดงผลข้อมูล เช่น Tableau, Power BI
# - ฐานข้อมูล เช่น SQL, NoSQL
#
# การวิเคราะห์ข้อมูลมีบทบาทสำคัญในการช่วยให้องค์กรและนักวิจัยสามารถตัดสินใจได้อย่างมีประสิทธิภาพโดยอ้างอิงจากข้อมูล

# %% [markdown]
# ## 2. Descriptive Analysis

# %% [markdown]
# ### Describing and Presenting Data
# - หลักสำคัญในการนำเสนอข้อม ได้แก่ ความถูกต้อง, ความกระชับ และความเข้าใจง่าย
# - นักวิจัยควรนำเสนอข้อมูลในลักษณะที่สามารถสะท้อนความถูกต้องของข้อมูลได้มากที่สุด
# - ข้อมูลเชิงตัวเลขสามารถแบ่งออกเป็นข้อมูลเชิงตัวเลข (เช่น เปอร์เซ็นต์, ค่าเฉลี่ย) หรือเชิงกราฟิก (ใช้วิธีการกราฟ)

# %% [markdown]
# ### Measures of Central Tendency

# %% [markdown]
# - ค่าเฉลี่ย (Mean) — ค่าเฉลี่ยทั่วไปและเป็นตัวชี้วัดของแนวโน้มเข้าสู่ศูนย์กลางที่พบบ่อยและมีประโยชน์มากที่สุด แต่อาจได้รับผลกระทบจากค่าที่สุดโต่ง (outliers)
#
# - ค่ามัธยฐาน (Median) — ค่ากลางของการแจกแจงข้อมูล ซึ่งได้รับผลกระทบน้อยกว่าจากค่าที่สุดโต่ง
#
# - ฐานนิยม (Mode) — ค่าที่พบมากที่สุดในชุดข้อมูล

# %%
import random
import statistics as st

# Generate a list of random integers
data = [random.randint(1, 100) for _ in range(20)]
data
# Out:
# [30, 53, 9, 80, 39, 13, 40, 1, 36, 31, 45, 45, 99, 93, 7, 66, 99, 5, 71, 100]

# %%
# mean
mean = st.mean(data)
mean
# Out:
# 48.1

# %%
# median

# %%
# mode

# %% [markdown]
# ### Measures of Variability

# %% [markdown]
# - การวัดการกระจายตัว (Measures of Variability) — สถิติเชิงพรรณนาที่แสดงข้อมูลเกี่ยวกับการกระจายหรือความแปรปรวนของชุดข้อมูล
#
# - **ความแปรปรวน (Variance)** — ค่าดัชนีเชิงตัวเลขที่แสดงความแปรปรวนในชุดข้อมูล
#
# - **ส่วนเบี่ยงเบนมาตรฐาน (Standard Deviation)** — ค่าที่แสดงความแปรปรวนโดยมีค่าเท่ากับรากที่สองของความแปรปรวน
#
# - **พิสัย (Range)** — ค่าต่างระหว่างคะแนนที่สูงที่สุดและต่ำที่สุดในชุดข้อมูล

# %%
# var

# %%
# sd

# %%
data_range = max(data) - min(data)
data_range
# Out:
# 99

# %% [markdown]
# ### Statistical graphs of data

# %% [markdown]
# > A picture is worth a thousand words!
#
#
# **Graphs for numerical data**:
# 1. Histograms
# 2. Frequency polygons
#
# **Graphs for categorical data**
# 1. Bar graphs
# 2. Pie

# %% [markdown]
# #### Histograms

# %%
# prompt: show the example of histogram

import matplotlib.pyplot as plt

# Sample data (you can replace this with your own data)
data = [random.randint(1, 100) for _ in range(50)]

# Create the histogram
plt.hist(data, bins=10, edgecolor='black')  # Adjust 'bins' for desired granularity

# Customize the plot (optional)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Random Data')

# Show the plot
plt.show()

# %% [markdown]
# #### Frequency polygons

# %%
import matplotlib.pyplot as plt

# Assuming 'data' is your existing data
n, bins, patches = plt.hist(data, bins=10, edgecolor='black')

bin_centers = (bins[:-1] + bins[1:]) / 2

bin_centers = [bins[0] - (bins[1]-bins[0])] + list(bin_centers) + [bins[-1] + (bins[-1]-bins[-2])]
n = [0] + list(n) + [0]

plt.plot(bin_centers, n, marker='o', linestyle='-')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Frequency Polygon of Random Data')

plt.show()

# %%
plt.plot(bin_centers, n, marker='o', linestyle='-')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Frequency Polygon of Random Data')

plt.show()

# %% [markdown]
# #### Bar Graph

# %%
# prompt: show the example of bar graph

import matplotlib.pyplot as plt

# Sample data for the bar graph
categories = ['A', 'B', 'C', 'D', 'E']
values = [25, 40, 15, 30, 20]

# Create the bar graph
plt.bar(categories, values, color='skyblue')

# Customize the plot
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Graph Example')

# Show the plot
plt.show()

# %% [markdown]
# #### Pie Chart

# %%
# prompt: show the example of pie chart

import matplotlib.pyplot as plt

# Sample data (replace with your actual numerical data)
data = {'A': 25, 'B': 35, 'C': 15, 'D': 25}

# Extract labels and values
labels = list(data.keys())
values = list(data.values())

# Create the pie chart
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=90)

# Customize the plot (optional)
plt.title('Pie Chart of Numerical Data')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Show the plot
plt.show()

# %% [markdown]
# ## 3. การทดสอบสมมติฐาน (Hypothesis Test)

# %% [markdown]
# การทดสอบสมมติฐานคือกระบวนการทางสถิติที่ใช้ในการตรวจสอบข้อสมมติที่เกี่ยวกับประชากร โดยพิจารณาจากตัวอย่างข้อมูล กระบวนการนี้ใช้เพื่อดูว่าข้อสมมติที่ตั้งไว้มีความเป็นไปได้หรือไม่เมื่อเปรียบเทียบกับข้อมูลที่สังเกตได้

# %% [markdown]
# #### ขั้นตอนหลักในการทดสอบสมมติฐาน
# 1. **ตั้งสมมติฐานศูนย์ (Null Hypothesis, $H_0$)**: เป็นข้อสมมติที่เราต้องการทดสอบ ซึ่งมักจะระบุว่าไม่มีความสัมพันธ์หรือความแตกต่างระหว่างตัวแปร เช่น สมมติว่าค่าเฉลี่ยของกลุ่มสองกลุ่มเท่ากัน
#
# 2. **ตั้งสมมติฐานทางเลือก (Alternative Hypothesis, $H_a$)**: เป็นข้อสมมติที่ตรงข้ามกับสมมติฐานศูนย์ โดยมักจะระบุว่ามีความสัมพันธ์หรือความแตกต่างระหว่างตัวแปร เช่น ค่าเฉลี่ยของกลุ่มหนึ่งสูงกว่าหรือต่ำกว่ากลุ่มอื่น
#
# 3. **กำหนดระดับนัยสำคัญ (Significance Level, $\alpha$)**: มักตั้งไว้ที่ 0.05 หรือ 0.01 ซึ่งเป็นค่าความน่าจะเป็นที่เรายอมรับได้ในการปฏิเสธสมมติฐานศูนย์อย่างผิดพลาด (Type I error)
#
# 4. **คำนวณค่าทดสอบ (Test Statistic)**: คำนวณค่าทางสถิติ เช่น ค่า $t$, ค่า $z$, หรือค่า $\chi^2$ ขึ้นอยู่กับประเภทของการทดสอบและการแจกแจงข้อมูล
#
# 5. **หาค่าความน่าจะเป็น (p-value)**: คำนวณค่า $p$ เพื่อตรวจสอบว่าผลลัพธ์ที่ได้มีโอกาสเกิดขึ้นได้มากน้อยเพียงใดภายใต้สมมติฐานศูนย์
#
# 6. **ตัดสินใจ (Decision)**: หากค่า $p$ ต่ำกว่าระดับนัยสำคัญ $\alpha$ ให้ปฏิเสธสมมติฐานศูนย์ แต่หาก $p$ มากกว่าหรือเท่ากับ $\alpha $ ให้ยอมรับสมมติฐานศูนย์
#
# #### ประเภทของการทดสอบสมมติฐาน
# - **ทดสอบค่าเฉลี่ย (t-test, z-test)**: ใช้เพื่อทดสอบค่าเฉลี่ยของประชากรหรือค่าเฉลี่ยระหว่างกลุ่ม
# - **การทดสอบความสัมพันธ์ (Correlation Test)**: ตรวจสอบว่ามีความสัมพันธ์ระหว่างตัวแปรสองตัวหรือไม่
# - **การวิเคราะห์ความแปรปรวน (ANOVA)**: ใช้เพื่อทดสอบว่าค่าเฉลี่ยของกลุ่มหลายกลุ่มแตกต่างกันหรือไม่
# - **การทดสอบไคสแควร์ (Chi-square Test)**: ใช้เพื่อทดสอบความเป็นอิสระระหว่างตัวแปรสองตัวที่เป็นเชิงหมวดหมู่
#
# การทดสอบสมมติฐานเป็นขั้นตอนสำคัญในการวิจัยและการวิเคราะห์ข้อมูล ซึ่งช่วยให้เราสามารถสรุปผลได้โดยมีพื้นฐานทางสถิติรองรับ

# %% [markdown]
# **Example 1**
#
# จากการสำรวจข้อมูลความสูงของคน Gen X พบว่ามีค่าความสูงอยู่ที่ 160 cm และมีค่า SD (σ=4) ทำการสำรวจคน Gen Y มา 16 คน ได้ค่าความสูงดังเฉลี่ยเป็น 164 จงใช้วิธีการทดสอบทางสมมติฐานเพื่อบอกว่าคน Gen X และคน Gen Y ที่ได้ทำการทดสอบนี้มีความสูงเท่ากันหรือไม่ โดยสมมติให้ SD ความของคน Gen X เท่ากับ Gen Y

# %%
# prompt: plot the graph of normal distribution with mu = 160 and sd = 4 for genX

import matplotlib.pyplot as plt
import numpy as np

# Define parameters
mu = 160  # Mean
sigma = 4  # Standard deviation
x = np.linspace(mu - 4 * sigma, mu + 4 * sigma, 100)  # Generate x values within 3 standard deviations of the mean
y = (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mu) / sigma)**2) #probability density function

# Plot the normal distribution
plt.plot(x, y)

# Customize the plot
plt.xlabel('Height (cm)')
plt.ylabel('Probability Density')
plt.title('Normal Distribution of GenX Height')
plt.grid(True)

# Show the plot
plt.show()

# %%
# prompt: plot the example of GenX and GenY with different mean

import matplotlib.pyplot as plt
import numpy as np

# Define parameters for GenX
mu_genx = 160  # Mean height for GenX
sigma_genx = 4  # Standard deviation for GenX

# Define parameters for GenY
mu_geny = 170  # Mean height for GenY
sigma_geny = 4  # Standard deviation for GenY (assumed equal to GenX)

# Generate x values within 3 standard deviations of the mean for both groups
x_genx = np.linspace(mu_genx - 3 * sigma_genx, mu_genx + 3 * sigma_genx, 100)
x_geny = np.linspace(mu_geny - 3 * sigma_geny, mu_geny + 3 * sigma_geny, 100)

# Calculate probability density function (PDF) for both groups
y_genx = (1 / (sigma_genx * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x_genx - mu_genx) / sigma_genx)**2)
y_geny = (1 / (sigma_geny * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x_geny - mu_geny) / sigma_geny)**2)

# Plot the normal distributions for both groups
plt.plot(x_genx, y_genx, label='GenX')
plt.plot(x_geny, y_geny, label='GenY')

# Customize the plot
plt.xlabel('Height (cm)')
plt.ylabel('Probability Density')
plt.title('Normal Distribution of GenX and GenY Heights')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
# prompt: show example distribution of GenY and compare with GenX

import matplotlib.pyplot as plt
import numpy as np

# Define parameters for GenX
mu_genx = 160  # Mean height of GenX
sigma_genx = 4  # Standard deviation of GenX height
n_genx = 10000 # Sample size for GenX (adjust as needed)

# Generate random height data for GenX based on normal distribution
genx_heights = np.random.normal(mu_genx, sigma_genx, n_genx)

# Define parameters for GenY (example values, replace with actual data)
mu_geny = 170  # Mean height of GenY (from your problem description)
sigma_geny = 4 # Assume same SD as GenX for comparison
n_geny = 10000 # Sample size for GenY

# Generate random height data for GenY based on normal distribution
geny_heights = np.random.normal(mu_geny, sigma_geny, n_geny)


# Plot the distributions
plt.figure(figsize=(10, 6))
plt.hist(genx_heights, bins=15, alpha=0.5, label='GenX', density=True)
plt.hist(geny_heights, bins=15, alpha=0.5, label='GenY', density=True)
plt.xlabel('Height (cm)')
plt.ylabel('Probability Density')
plt.title('Distribution of Heights: GenX vs. GenY')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
# prompt: show the example of hypothesis test

import scipy.stats as stats

# Given data
mu = 160  # Population mean (Gen X height)
sigma = 4  # Population standard deviation (Gen X height)
n = 16  # Sample size (Gen Y)
x_bar = 164  # Sample mean (Gen Y height)

# Define hypotheses
# H0: mu_GenX = mu_GenY (Gen X and Gen Y have the same mean height)
# H1: mu_GenX != mu_GenY (Gen X and Gen Y have different mean heights)

# Calculate the test statistic (z-score)
z = (x_bar - mu) / (sigma / (n**0.5))

# Significance level (alpha)
alpha = 0.05  # Common significance level

# Calculate the critical values for a two-tailed test
critical_value_lower = stats.norm.ppf(alpha / 2)
critical_value_upper = stats.norm.ppf(1 - alpha / 2)


# Make a decision
print(f"z-score: {z}")
print(f"Critical values: ({critical_value_lower}, {critical_value_upper})")

if z < critical_value_lower or z > critical_value_upper:
    print("Reject the null hypothesis.")
    print("There is sufficient evidence to suggest that the mean height of Gen X and Gen Y are different.")
else:
    print("Fail to reject the null hypothesis.")
    print("There is not enough evidence to suggest a difference in mean height between Gen X and Gen Y.")

# Calculate p-value
p_value = 2 * (1 - stats.norm.cdf(abs(z))) # two-tailed test

print(f"p-value: {p_value}")
if p_value < alpha:
  print("Reject the null hypothesis.")
else:
  print("Fail to reject the null hypothesis.")
# Out:
# z-score: 4.0
# Critical values: (-1.9599639845400545, 1.959963984540054)
# Reject the null hypothesis.
# There is sufficient evidence to suggest that the mean height of Gen X and Gen Y are different.
# p-value: 6.334248366623996e-05
# Reject the null hypothesis.

# %% [markdown]
# ## 4. Correlation Analysis

# %% [markdown]
# **ความสัมพันธ์ (Correlation)** คือการวัดระดับของการเกี่ยวข้องกันของตัวแปรต่าง ๆ ซึ่งช่วยให้ผู้วิจัยด้านธุรกิจสามารถวิเคราะห์ได้ว่าตัวแปรสองตัวมีความสัมพันธ์กันอย่างไร ตัวอย่างเช่น นักวิจัยสามารถใช้การวิเคราะห์ความสัมพันธ์เพื่อตรวจสอบว่าราคาหุ้นของสายการบินสองแห่งมีแนวโน้มเพิ่มขึ้นหรือลดลงในลักษณะที่สอดคล้องกันหรือไม่

# %% [markdown]
# Pearson Product-Moment Correlation Coefficient
#
# $r = \frac{\sum_{i=1}^{n}(x_i - \bar{x})(y_i - \bar{y})}{\sqrt{\sum_{i=1}^{n}(x_i - \bar{x})^2 \sum_{i=1}^{n}(y_i - \bar{y})^2}} \tag{1}$
#
# where $-1 \le r \le 1$

# %% [markdown]
# | $|r|$      | Correlation                 |
# |:-----------|:----------------------------|
# | 0.80 - 1   | Very strong correlation     |
# | 0.60 - 0.8 | Strong correlation          |
# | 0.40 - 0.6 | Moderate correlation        |
# | 0.20 - 0.4 | Weak correlation            |
# | 0.00 - 0.2 | Very weak or no correlation |

# %%
# prompt: create some example of correlation

import numpy as np
import matplotlib.pyplot as plt

# Generate sample data with a positive correlation
np.random.seed(0)  # for reproducibility
x = np.random.rand(50)
y = 2*x + np.random.randn(50) * 0.3 # Add some noise

# Calculate the correlation coefficient
correlation_coefficient = np.corrcoef(x, y)[0, 1]

# Plot the data points
plt.scatter(x, y)
plt.title(f"Positive Correlation (r = {correlation_coefficient:.2f})")
plt.xlabel("X")
plt.ylabel("Y")

# Add a trendline (optional)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")

plt.show()

# Generate sample data with a negative correlation
x = np.random.rand(50)
y = -2*x + np.random.randn(50) * 0.5 # Add some noise


# Calculate the correlation coefficient
correlation_coefficient = np.corrcoef(x, y)[0, 1]

# Plot the data points
plt.scatter(x, y)
plt.title(f"Negative Correlation (r = {correlation_coefficient:.2f})")
plt.xlabel("X")
plt.ylabel("Y")

# Add a trendline (optional)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")

plt.show()

# Generate sample data with no correlation
x = np.random.rand(50)
y = np.random.randn(50) #random noise

# Calculate the correlation coefficient
correlation_coefficient = np.corrcoef(x, y)[0, 1]

# Plot the data points
plt.scatter(x, y)
plt.title(f"No Correlation (r = {correlation_coefficient:.2f})")
plt.xlabel("X")
plt.ylabel("Y")

plt.show()

# %%
import numpy as np

# Sample data (replace with your own data)
x = np.array([61, 63, 67, 69, 70, 74, 76, 81, 86, 91, 95, 97])
y = np.array([4.280, 4.080, 4.420, 4.170, 4.480, 4.300, 4.820, 4.700, 5.110, 5.130, 5.640, 5.560])

plt.scatter(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# Calculate the correlation coefficient
correlation_coefficient = np.corrcoef(x, y)[0, 1]

# Print the result
print("Correlation coefficient:", correlation_coefficient)
# Out:
# Correlation coefficient: 0.9482003279477094

# %% [markdown]
# ## 5. Regression Analysis

# %% [markdown]
# **การวิเคราะห์การถดถอย (Regression Analysis)**
#
# คือวิธีทางสถิติที่ใช้เพื่อศึกษาความสัมพันธ์ระหว่างตัวแปรต้น (Independent Variable) กับตัวแปรตาม (Dependent Variable) โดยเฉพาะอย่างยิ่งในกรณีที่เราต้องการทำนายค่าในอนาคตหรือวิเคราะห์ปัจจัยที่มีผลกระทบต่อตัวแปรตาม
#
# ในภาพรวม การวิเคราะห์การถดถอยมักใช้เพื่อ:
#
# - ทำนายค่า – ใช้ตัวแปรต้นในการพยากรณ์หรือคาดการณ์ค่าของตัวแปรตาม
# - หาความสัมพันธ์ – ศึกษาความสัมพันธ์เชิงสาเหตุระหว่างตัวแปรต้นและตัวแปรตาม เพื่อดูว่าตัวแปรใดมีผลอย่างมีนัยสำคัญต่อการเปลี่ยนแปลงของตัวแปรตาม
# - ประมาณค่าของผลกระทบ – ดูว่าตัวแปรต้นแต่ละตัวส่งผลต่อตัวแปรตามมากน้อยเพียงใด

# %%
import numpy as np

# Sample data (replace with your own data)
x = np.array([61, 63, 67, 69, 70, 74, 76, 81, 86, 91, 95, 97])
y = np.array([4.280, 4.080, 4.420, 4.170, 4.480, 4.300, 4.820, 4.700, 5.110, 5.130, 5.640, 5.560])

plt.scatter(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# The equation of a simple regression line is given by:
#
# $
# \hat{Y} = b_0 + b_1 X \tag{2}
# $
#
# where:
# - $ \hat{Y} $ is the predicted (dependent) variable.
# - $ X $ is the independent variable.
# - $ b_0 $ is the intercept, representing the expected value of $ Y $ when $ X = 0 $.
# - $ b_1 $ is the slope coefficient, indicating the change in $ Y $ for a one-unit increase in $ X $.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data (replace with your own data)
x = np.array([61, 63, 67, 69, 70, 74, 76, 81, 86, 91, 95, 97])
y = np.array([4.280, 4.080, 4.420, 4.170, 4.480, 4.300, 4.820, 4.700, 5.110, 5.130, 5.640, 5.560])

# Example
b1 = 0.04
b0 = 1.5
y_pred = b0 + b1 * x

# Plot the scatter plot and the regression line
plt.scatter(x, y, label='Data Points')
plt.plot(x, y_pred, color='red', label='Regression Line')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# #### Least Squares Analysis
#
# **Least Squares Analysis** is a statistical method used to develop a regression model by minimizing the sum of the squared differences between the observed values and the values predicted by the model. This approach ensures that the line of best fit, which represents the regression model, is as close as possible to all observed data points.

# %% [markdown]
# The value of $b_1$, the slope of the regression line in the Least Squares Analysis, is calculated using the formula:
#
# $
# b_1 = \frac{\sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})}{\sum_{i=1}^{n} (X_i - \bar{X})^2} \tag{3}
# $

# %% [markdown]
# The value of $b_0$, the intercept of the regression line in the Least Squares Analysis, is calculated using the formula:
#
# $b_0 = \bar{Y} - b_1 \bar{X} \tag{4}$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample data (replace with your own data)
x = np.array([61, 63, 67, 69, 70, 74, 76, 81, 86, 91, 95, 97])
y = np.array([4.280, 4.080, 4.420, 4.170, 4.480, 4.300, 4.820, 4.700, 5.110, 5.130, 5.640, 5.560])

# Calculate the means of x and y
x_mean = np.mean(x)
y_mean = np.mean(y)

# Calculate the slope (b1) using the least squares formula
numerator = np.sum((x - x_mean) * (y - y_mean))
denominator = np.sum((x - x_mean)**2)
b1 = numerator / denominator

# Calculate the intercept (b0) using the least squares formula
b0 = y_mean - (b1 * x_mean)

# Create the regression line
y_pred = b0 + b1 * x

# Plot the scatter plot and the regression line
plt.scatter(x, y, label='Data Points')
plt.plot(x, y_pred, color='red', label='Regression Line')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Least Squares Regression')
plt.legend()
plt.show()

# Print the equation of the regression line
print(f"Regression Equation: y = {b0:.4f} + {b1:.4f}x")
# Out:
# Regression Equation: y = 1.5698 + 0.0407x

# %%
# prompt: z score 95% z value

import scipy.stats as stats

# 95% confidence interval corresponds to a z-value of approximately 1.96
z_value = stats.norm.ppf(0.975)  # 0.975 for two-tailed test
print(f"The z-value for a 95% confidence interval is approximately: {z_value}")
